# %%
pip install Scweet
# Out:
# ...
#   Created wheel for Scweet: filename=Scweet-1.0-py3-none-any.whl size=9424 sha256=98de44b295833980476288eeab3faec1b161f2e63665746a02bd92cc9f616c2e
#   Stored in directory: c:\users\ashima singhal\appdata\local\pip\cache\wheels\ae\a9\a5\2593b83ff655a81bd197e8a937a212523ce966477c39374ba3
# Successfully built Scweet
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install selenium
# !pip install pandas
# !pip install python-dotenv
# !pip install chromedriver-autoinstaller
# !pip install urllib3

# %%
from Scweet.scweet import scrap
from Scweet.user import get_user_information, get_users_following, get_users_followers

# %%
keywords = ['clusters','Covid-19','Covid','vaccine','Moderna','Pfizer','Sinovac','AstraZeneca','coronavirus','cases','visited','infectious',
'diseases','tracing','NCID','DORSCON','dormitories','dormitory','foreign','bubble','Circuit','Road','Drive','Park','Lane','Link','Street','Boulevard',
'Avenue','Grove','Crescent','Close','Central','Rise','Terrace','Walk','Sata','Maxwell','Marsiling','Wuhan','Guangzhou','Hubei','Seletar','Sentosa','Jurong',
'Kallang','Punggol','Woodlands','Kah', 'Hyatt','Fusionopolis','Vista','Fong','Sengkang','SingPost','Mustafa','Cassia','Wai','Fullerton','Hang','WizLearn',
'Singtel','Keppel','Mooi','vaccination','vaccines','cluster','Johor','strain','strains','Quay','Jalan','Gardens','North','East','West','South','Hill','View'
,'Rise','Square','Taman','Village','Estate','Green','Heights','Ridge','Way','Place','Ring','Garden','Lorong','Circle','Centre','Lengkok','Kampong','Mount',
'Track','Sector','Loop','Tanjong','Kallang','Geylang','Bukit','Hospital','Hotel','Scarlet','Fairmont','Parkroyal','Beach','Swissotel','Conrad','Mandarin',
'Marina','Pan','Ritz-Carlton','Hilton','Regis','Holiday','Capella','Stamford','House','Tower','Esplanade','Changi','Expo','Suntec','City','Istana','Complex',
'Temasek','Victoria','Court','National','Museum','Nanyang','Temple','Monastery','Buddhist','Masjid','Cathedral','Church','School','College','University',
'Australia', 'Austria', 'Bahamas','Bangladesh', 'Belgium', 'Bhutan', 'Brazil', 'Brunei', 'Canada', 'Republic', 'China', 'Denmark','Guinea','Finland', 
'France', 'Germany', 'Greece', 'Guinea', 
'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Japan', 
'Korea', 'Hong', 'Malaysia', 'Mexico', 
'Mongolia', 'Myanmar', 'Nepal', 'Netherlands', 'Zealand',  
'Norway', 'Pakistan', 'Philippines', 'Poland', 'Portugal', 
'Qatar', 'Russia', 'Arabia', 'Singapore', 'Slovakia', 'Slovenia', 
'Somalia','Spain', 'Lanka', 'Sweden', 'Switzerland', 'Syria', 'Taiwan', 'Thailand',
'Turkey', 'United', 
'Vatican', 'Vietnam','NCID','A*STAR', 'ACS', 'ACM', 'ACPS', 'ACRES', 'ACS(I)', 'ACSS', 
'ACJC', 'AG', 'AGC', 'AHS', 'AISS', 'AJ', 'AJC', 'AMK', 'AMP','SATA', 'APPLES', 'AR', 'ASRJC', 'AWARE', 'AWWA', 'AY', 
'AYE', 'BB', 'BBSS', 'BC', 'BCA', 'BCM', 'BBDC', 'BBT', 'BDK', 'BDS', 'BF', 'BGR', 'BJ', 'BKE', 'BMT', 'BPGHS', 'BPLRT', 'BPP', 'BPT', 'BPJ', 
'BRT', 'BSEP', 'BTO', 'BTS', 'BTT', 'BTYSS', 'BVSS', 'BWSS', 'CAAS', 'CBD', 'CBP', 'CBPU', 'CCA', 'CCC', 'CCHS', 'CCK', 'CCL', 'CCR', 'CDAC', 
'CDC', 'CEPAS', 'CHC', 'CHIJ', 'CHS', 'CNB', 'CID', 'CIP', 'CIQ', 'CIS', 'CJ', 'CJC', 'CMPB', 'CNA', 'COE', 'CPF', 'CPIB', 'CRL', 'CS', 'CSC', 
'CSM', 'CTE', 'CTSS', 'CWO', 'CWP', 'CWS', 'DART', 'DBS', 'DBSS', 'DHS', 'DJ', 'DMN', 'DPP', 'DR', 'DSO', 'DSTA', 'DTE', 'DTL', 'EC', 
'ECP', 'EDB', 'EDP', 'eGAP', 'EJC', 'EP', 'ERP', 'EWL', 'EFSS', 'FAS', 'FCBC', 'FG', 'FHSS', 'FMSS', 'FMPS', 'FTT', 'FT', 'GAD', 'GAS', 'GB', 
'GBTB', 'GCE', 'GCM', 'GCT', 'GE', 'GEP', 'GIS', 'GP', 'GRC', 'GSS', 'GST', 'GV', 'GWA', 'GWC', 'GYSS', 'HCI', 'HCJC', 'HDB', 'HEB', 'HG', 
'HOGC', 'HIP', 'HPB', 'HPPS', 'HS', 'HSA', 'HYSS', 'HSCS', 'IC', 'ICBC', 'ICA', 'ICS', 'IDA', 'IJC', 'IMDA', 'IMH', 'IO', 'IP', 'IPPT', 'IR', 
'IRO', 'ISA', 'ISD', 'ITE', 'J8', 'JB', 'JC', 'JCA', 'JBJ', 'JEM', 'JEMP', 'JJC', 'JP', 'JPJC', 'JPS', 'JRL', 'JSS', 'JTC',
'KIV', 'KJE', 'KK', 'KL', 'KMSPKS', 'KPE', 'KTPH', 'LCK', 'LCCS', 'LHL', 'LKCM', 'LKY', 'LRT', 'LTA', 'MAH', 'MAS', 'MBFC', 'MBLM', 
'MBS','MBSC', 'MC', 'MCD', 'MCE', 'MCI', 'MCS', 'MCYS', 'MDA', 'MDIS', 'MENDAKI', 'MGS', 'MI', 'MJC', 'MJR', 'MINDEF', 'MINDS', 'MOE', 'MOF', 
'MOH', 'MOM', 'MOS', 'MRT', 'MSCP', 'MSHS', 'MSL', 'MSS', 'MUIS', 'NAPS', 'NAFA', 'NAPFA', 'NAS', 'NCC', 'NCDCC', 'NCMP', 'NCS', 'NCSS', 
'NDP', 'NE', 'NEA', 'NEL', 'NETS', 'NHG', 'NHHS', 'NIE', 'NJC', 'NKF', 'NLB', 'NMP', 'NMS', 'NP', 'NPARKS', 'NPCC', 'NRIC', 'NRP', 'NS', 
'NSE', 'NSF', 'NSL', 'NSTB', 'NTC', 'NTFGH', 'NTPS', 'NTU', 'NTUC', 'NUH', 'NUHS', 'NUS', 'NUSHS', 'NWC', 'NYGH', 'NYK', 'NYP', 'NYPS', 
'NYJC', 'OB', 'OBS', 'OCBC', 'OCR', 'OCS', 'OFS', 'OPSS', 'ORD', 'OSS', 'OUB', 'O$P$', 'PA', 'PAP', 'PCK', 'PDI', 'PE', 'PES', 'PFP', 'PG', 
'PGP', 'PHS', 'PIE', 'PJC', 'PLQ', 'PLS', 'PLU', 'POSB', 'PROGRESS', 'PS', 'PSA', 'PSC', 'PSLE', 'PSP', 'PSR', 'PUB', 'PWD', 'PR', 'PT', 
'PDL', 'PLMGPS', 'PLMGSS', 'QDL', 'QPS', 'RC', 'RCR', 'RCS', 'RCY', 'REP', 'RGPS', 'RGS', 'RI', 'RJ', 'RMPS', 'ROM', 'RP', 'RRP', 'RS', 
'RSAF', 'RSN', 'RSS', 'RWS', 'RVHS', 'RVRC', 'SAF', 'SAFRA', 'SAJC', 'SAL', 'SAM', 'SANA', 'SAP', 'SAR', 'SAS', 'SAWL', 'SBF', 'SBI', 'SBM', 
'SBS', 'SBW', 'SBYM', 'SC', 'SCDF', 'SCGS', 'SCS', 'SDA', 'SDJ', 'SDP', 'SDU', 'SERS', 'SFI', 'SG', 'SGH', 'SGSS', 'SGX', 'SIA', 'SICC', 
'SILS', 'SIM', 'SINDA', 'SIO', 'SIT', 'SJAB', 'SJI', 'SJII', 'SJIJ', 'SK', 'SKGH', 'SLA', 'SLF', 'SLO', 'SLS', 'SLT', 'SMF', 'SMC', 'SMRT', 
'SMSS', 'SMU', 'SNO', 'SNOC', 'SNPC', 'SOS', 'SOTA', 'SP', 'SPA', 'SPC', 'SPCA', 'SPF', 'SPH', 'SPG', 'SPS', 'SRCS', 'SRJC', 'SS', 'SSC', 
'SSDC', 'SSO', 'SST', 'ST', 'STAR', 'STB', 'STV', 'SUSS', 'SUTD', 'SVPS', 'SYAS', 'SYF', 'SYFC', 'SYOGOC', 'SYT', 'TA', 'TBP', 
'TCHS', 'TCS', 'TEL', 'TH', 'TIBS', 'TJC', 'TKGS', 'TKSS', 'TM', 'TMJC', 'TMS', 'TNS', 'TNP', 'TOP', 'TP', 'TPY', 'TPJC', 'TPS', 
'TPSS', 'TTC', 'TTS', 'TTSH', 'TSS', 'UEN', 'UOB', 'URA', 'USS', 'UWC', 'VIA', 'VJC', 'VS', 'VSS', 'VWO', 'WDL', 'WDP', 'WPS', 'WGS', 
'WP', 'WS', 'WSS', 'WWP', 'WWSS', 'XMM', 'XHH', 'XMS', 'YCKSS', 'YHSS', 'YJC', 'YIJC', 'YLL', 'YP', 'YSS', 'YTSS', 'YIS', 'YNC', 'AEIS', 
'AIS', 'BKT', 'BT', 'CC', 'DCIS', 'DCS', 'DP', 'DTF', 'FDW', 'GEMS', 'GESS', 'GIIS', 'GIRO', 'HSBC', 'HWA', 'IB', 'IIS', 'IRAS', 'ISS', 'LFS', 
'LOA', 'LOC', 'NISS', 'OIC', 'OMV', 'PARF', 'PCN', 'PQP', 'SAIS', 'SJS', 'SLE', 'SNEC', 'SSS', 'TPE', 'TT', 'TWS', 'UWCSEA', 'XLB']

# %%
data = scrap(words=keywords, start_date="2021-04-01", max_date="2021-04-30", from_account = None,interval=1, 
      headless=True, display_type="Top", save_images=False, 
             resume=False, filter_replies=True, proximity=True)
# Out:
# Scraping on headless mode.
# looking for tweets between 2021-04-01 and 2021-04-02 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2021-04-02%20since%3A2021-04-01%20%20-filter%3Areplies&src=typed_query&lf=on
# scroll  1
# Tweet made at: 2021-04-01T23:54:34.000Z is found.
# Tweet made at: 2021-04-01T23:58:34.000Z is found.
# Tweet made at: 2021-04-01T23:53:56.000Z is found.
# Tweet made at: 2021-04-01T23:54:58.000Z is found.
# Tweet made at: 2021-04-01T23:55:38.000Z is found.
# Tweet made at: 2021-04-01T23:55:27.000Z is found.
# Tweet made at: 2021-04-01T23:53:07.000Z is found.
# Tweet made at: 2021-04-01T23:59:00.000Z is found.
# Tweet made at: 2021-04-01T23:58:12.000Z is found.
# Tweet made at: 2021-04-01T23:59:11.000Z is found.
# Tweet made at: 2021-04-01T23:59:01.000Z is found.
# scroll  2
# Tweet made at: 2021-04-01T23:53:56.000Z is found.
# Tweet made at: 2021-04-01T23:56:29.000Z is found.
# Tweet made at: 2021-04-01T23:59:14.000Z is found.
# ...

# %%
data.head()
# Out:
#             UserScreenName          UserName                 Timestamp  \
# 0      Dr. Danielle Lawson  @DanielleFLawson  2021-04-01T23:54:34.000Z
# 1  Park Wolfpack Wrestling     @WolfpackPark  2021-04-01T23:58:34.000Z
# 2       The Citizen Pundit   @1citizenpundit  2021-04-01T23:53:56.000Z
# 3     #SurvivedAndPunished        @COLBYLENZ  2021-04-01T23:54:58.000Z
# 4            justjessylynn      @jessylynn40  2021-04-01T23:55:38.000Z
#
#                                                 Text  \
# 0  “How do we cover from COVID, environmental dis...
# 1  JC has been awarded our - hopefully - only eve...
# 2  Employers can't require Covid-19 vaccination u...
# 3  People with #COVID19 at CCWF women's prisons a...
# 4  This is why we can’t have nice things. 552k de...
#
#                                        Embedded_text Emojis Comments Likes  \
# 0                                                                  1     1
# 1
# ...

# %%
data.to_csv(path)
